# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshwarjayabal/NumPy/blob/main/NumPy_Ufuncs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**NumPy ufuncs**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Without ufunc, we can use Python's built-in zip() method

x = [1, 2, 3, 4]
y = [4, 5, 6, 7]
z = []

for i, j in zip(x, y):
  z.append(i + j)
print(z)
# Out:
# [5, 7, 9, 11]

# %%
# NumPy has a ufunc for this, called add(x, y) that will produce the same result.

import numpy as np
x = [1, 2, 3, 4]
y = [4, 5, 6, 7]

z = np.add(x,y)
print(z)
# Out:
# [ 5  7  9 11]

# %% [markdown]
# #**Create Your Own ufunc**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create your own ufunc for addition

import numpy as np

def myadd(x, y):
  return x+y

myadd = np.frompyfunc(myadd, 2, 1)

print(myadd([1, 2, 3, 4], [5, 6, 7, 8]))
# Out:
# [6 8 10 12]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

print(type(np.add))
# Out:
# <class 'numpy.ufunc'>

# %%
import numpy as np

if type(np.add) == np.ufunc:
  print('add is ufunc')
else:
  print('add is not ufunc')
# Out:
# add is ufunc

# %% [markdown]
# #**Ufunc Simple Arithmetic**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr1 = np.array([10, 11, 12, 13, 14, 15])
arr2 = np.array([20, 21, 22, 23, 24, 25])

x = np.add(arr1,arr2)
y = np.subtract(arr1,arr2)
z = np.multiply(arr1,arr2)
a = np.divide(arr1,arr2)
b = np.power(arr1,arr2)
c = np.mod(arr1,arr2)
d = np.remainder(arr1,arr2)
e = np.divmod(arr1,arr2)
f = np.absolute(arr1,arr2)


print(x)
print(y)
print(z)
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# [30 32 34 36 38 40]
# [-10 -10 -10 -10 -10 -10]
# [200 231 264 299 336 375]
# [0.5        0.52380952 0.54545455 0.56521739 0.58333333 0.6       ]
# [ 7766279631452241920  3105570700629903195  5729018530666381312
#  -4649523274362944347 -1849127232522420224  1824414961309619599]
# [10 11 12 13 14 15]
# [10 11 12 13 14 15]
# (array([0, 0, 0, 0, 0, 0]), array([10, 11, 12, 13, 14, 15]))
# [10 11 12 13 14 15]

# %%
# The add() function sums the content of two arrays, and return the results in a new array.
# This will return [30 32 34 36 38 40] which is the sums of 10+20, 11+21, 12+22 etc.

# The subtract() function subtracts the values from one array with the values from another array, and return the results in a new array.
# This will return [-10 -1 8 17 26 35] which is the result of 10-20, 20-21, 30-22 etc.

# The multiply() function multiplies the values from one array with the values from another array, and return the results in a new array.
# This will return [200 420 660 920 1200 1500] which is the result of 10*20, 20*21, 30*22 etc

# The divide() function divides the values from one array with the values from another array, and return the results in a new array.
# This will return [3.33333333 4. 3. 5. 25. 1.81818182] which is the result of 10/3, 20/5, 30/10 etc.

# The power() function rises the values from the first array to the power of the values of the second array, and return the results in a new array.
# This  will return [1000 3200000 729000000 6553600000000 2500 0] which is the result of 10*10*10, 20*20*20*20*20, 30*30*30*30*30*30 etc.

# Both the mod() and the remainder() functions return the remainder of the values in the first array corresponding to the values in the second array, and return the results in a new array.
# This will return [1 6 3 0 0 27] which is the remainders when you divide 10 with 3 (10%3), 20 with 7 (20%7) 30 with 9 (30%9) etc.

# The divmod() function return both the quotient and the mod. The return value is two arrays, the first array contains the quotient and second array contains the mod.
# This will return: (array([3, 2, 3, 5, 25, 1]), array([1, 6, 3, 0, 0, 27])) The first array represents the quotients, (the integer value when you divide 10 with 3, 20 with 7, 30 with 9 etc.
# The second array represents the remainders of the same divisions.

# Both the absolute() and the abs() functions do the same absolute operation element-wise but we should use absolute() to avoid confusion with python's inbuilt math.abs()
# this will return [1 2 1 2 3 4].

# %% [markdown]
# #**ufunc Rounding Decimals**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.trunc([-3.1666, 3.6667])

print(arr)
# Out:
# [-3.  3.]

# %%
import numpy as np

arr = np.fix([-3.1666, 3.6667])

print(arr)
# Out:
# [-3.  3.]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.around(3.1666, 2)

print(arr)
# Out:
# 3.17

# %%
import numpy as np

arr = np.around(3.1666, 1)

print(arr)
# Out:
# 3.2

# %%
import numpy as np

arr = np.around(3.1666, 3)

print(arr)
# Out:
# 3.167

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.floor([-3.1666, 3.6667])

print(arr)
# Out:
# [-4.  3.]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.ceil([-3.1666, 3.6667])

print(arr)
# Out:
# [-3.  4.]

# %% [markdown]
# #**ufunc NumPy Logs**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.arange(1, 10)

print(np.log2(arr))
# Out:
# [0.         1.         1.5849625  2.         2.32192809 2.5849625
#  2.80735492 3.         3.169925  ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.arange(1, 10)

print(np.log10(arr))
# Out:
# [0.         0.30103    0.47712125 0.60205999 0.69897    0.77815125
#  0.84509804 0.90308999 0.95424251]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.arange(1, 10)

print(np.log(arr))
# Out:
# [0.         0.69314718 1.09861229 1.38629436 1.60943791 1.79175947
#  1.94591015 2.07944154 2.19722458]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import log
import numpy as np

nplog = np.frompyfunc(log, 2, 1)

print(nplog(100, 15))
# Out:
# 1.7005483074552052

# %% [markdown]
# #**ufunc NumPy Summations**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr1 = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])

newarr = np.add(arr1, arr2)

print(newarr)
# Out:
# [2 4 6]

# %%
import numpy as np

arr1 = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])

newarr = np.sum([arr1, arr2])

print(newarr)
# Out:
# 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr1 = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])

newarr = np.sum([arr1, arr2], axis=1)

print(newarr)
# Out:
# [6 6]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([1, 2, 3])

newarr = np.cumsum(arr)

print(newarr)
# Out:
# [1 3 6]

# %% [markdown]
# #**ufunc NumPy Products**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])

x = np.prod(arr)

print(x)
# Out:
# 24

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([5, 6, 7, 8])

x = np.prod([arr1, arr2])

print(x)
# Out:
# 40320

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([5, 6, 7, 8])

newarr = np.prod([arr1, arr2], axis=1)

print(newarr)
# Out:
# [  24 1680]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([5, 6, 7, 8])

newarr = np.cumprod(arr)

print(newarr)
# Out:
# [   5   30  210 1680]

# %% [markdown]
# #**ufunc NumPy Differences**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([10, 15, 25, 5])

newarr = np.diff(arr)

print(newarr)
# Out:
# [  5  10 -20]

# %%
# Returns: [5 10 -20] because 15-10=5, 25-15=10, and 5-25=-20

# We can perform this operation repeatedly by giving parameter n.

# E.g. for [1, 2, 3, 4], the discrete difference with n = 2 would be [2-1, 3-2, 4-3] = [1, 1, 1] ,
# then, since n=2, we will do it once more, with the new result: [1-1, 1-1] = [0, 0]

# %%
import numpy as np

arr = np.array([10, 15, 25, 5])

newarr = np.diff(arr, n=2)

print(newarr)
# Out:
# [  5 -30]

# %% [markdown]
# #**NumPy LCM Lowest Common Multiple**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

num1 = 4
num2 = 6

x = np.lcm(num1, num2)

print(x)
# Out:
# 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([3, 6, 9])

x = np.lcm.reduce(arr)

print(x)
# Out:
# 18

# %%
import numpy as np

arr = np.arange(1, 11)

x = np.lcm.reduce(arr)

print(x)
# Out:
# 2520

# %% [markdown]
# #**ufunc NumPy GCD Greatest Common Denominator**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

num1 = 6
num2 = 9

x = np.gcd(num1, num2)

print(x)
# Out:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([20, 8, 32, 36, 16])

x = np.gcd.reduce(arr)

print(x)
# Out:
# 4

# %% [markdown]
# #**NumPy Set Operations**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([1, 1, 1, 2, 3, 4, 5, 5, 6, 7])

x = np.unique(arr)

print(x)
# Out:
# [1 2 3 4 5 6 7]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([3, 4, 5, 6])

newarr = np.union1d(arr1, arr2)

print(newarr)
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([3, 4, 5, 6])

newarr = np.intersect1d(arr1, arr2, assume_unique=True)

print(newarr)
# Out:
# [3 4]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

set1 = np.array([1, 2, 3, 4])
set2 = np.array([3, 4, 5, 6])

newarr = np.setdiff1d(set1, set2, assume_unique=True)

print(newarr)
# Out:
# [1 2]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

set1 = np.array([1, 2, 3, 4])
set2 = np.array([3, 4, 5, 6])

newarr = np.setxor1d(set1, set2, assume_unique=True)

print(newarr)
# Out:
# [1 2 5 6]
